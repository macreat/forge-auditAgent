# %% [markdown]
# # Validation leakage
# The validation split reuses training samples. Reproduces the TRAIN ∩ VALIDATION ≠ ∅ failure (severity 9, category `splits`).

# %%
import numpy as np

# 100 training samples (indices 0..99).
train_ids = np.arange(0, 100)

# BUG: validation reuses samples 50..149, overlapping training on 50..99.
val_ids = np.arange(50, 150)
