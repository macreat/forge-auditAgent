# %% [markdown]
# # Train/test overlap (fixed)
# The test split is now disjoint from training. Fixes the TRAIN ∩ TEST ≠ ∅ failure.

# %%
import numpy as np

# 80 training samples (indices 0..79).
train_ids = np.arange(0, 80)

# FIXED: test uses disjoint samples 80..119.
test_ids = np.arange(80, 120)
