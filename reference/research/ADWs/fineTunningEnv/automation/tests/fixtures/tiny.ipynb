# %% [markdown]
# # Tiny notebook
# Minimal valid notebook used by the IR/IO unit tests.

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X = np.arange(10).reshape(5, 2)
y = np.arange(5)
