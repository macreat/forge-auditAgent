# %% [markdown]
# # Validation leakage (fixed)
# The validation split is now disjoint from training. Fixes the TRAIN ∩ VALIDATION ≠ ∅ failure.

# %%
import numpy as np

# 100 training samples (indices 0..99).
train_ids = np.arange(0, 100)

# FIXED: validation uses disjoint samples 100..149.
val_ids = np.arange(100, 150)
