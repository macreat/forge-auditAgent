# %% [markdown]
# # Kernel hang
# An unbounded loop. The executor's per-cell timeout must interrupt this cell and produce a severity-10 execution finding (threat-matrix RED case) — never hanging the pipeline.

# %%
while True:
    pass
